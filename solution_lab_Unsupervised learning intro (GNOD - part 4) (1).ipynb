# %%
#import laibraries
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("spotiy_featuers2.csv")

# %%
df
# Out:
#                                                   songs              artist  \
# 0                       Southernplayalisticadillacmuzik             Outkast
# 1     Learn How to Watch (feat. Mac Miller & MadeinTYO)             Carnage
# 2                      Allegations (feat. Pooh Shiesty)               BIG30
# 3                                          No Profanity        Pooh Shiesty
# 4                                             All Black             G Herbo
# ...                                                 ...                 ...
# 4027                                 Still Ridin' Clean         Project Pat
# 4028  Stay Fly (feat. Slim Thug, Trick Daddy & Proje...       Three 6 Mafia
# 4029                               I've Been Everywhere         Johnny Cash
# 4030                                    Cheese and Dope         Project Pat
# 4031                                           DOGTOOTH  Tyler, The Creator
#
#                                        uri  \
# 0     spotify:track:2pMAmZdHfQHyqJCXJbfhK3
# 1     spotify:track:5tErNrwK58SgLMjZXJ5fdY
# 2     spotify:track:3oW1FNqsSJVgxjE9rqgpDX
# 3     spotify:track:2fcrnYXo5BP1RjzhIgV0v9
# 4     spotify:track:1cwGnaxEAu7fnt8YYROisL
# ...                                    ...
# 4027  spotify:track:5KjeQtJQDFCMurnXYlpDz4
# 4028  spotify:track:1mf27pj8fn7GH4CehQxOtO
# 4029  spotify:track:59J3FhCGYl18G3ouDReUge
# 4030  spotify:track:5o0GRUA7okGPALKyEyQabz
# 4031  spotify:track:0judK8TqYfvwUohBngUxrE
#
#                                          audio_features  danceability  energy  \
# 0     [{'danceability': 0.691, 'energy': 0.834, 'key...         0.691   0.834
# 1     [{'danceability': 0.547, 'energy': 0.737, 'key...         0.547   0.737
# 2     [{'danceability': 0.664, 'energy': 0.42, 'key'...         0.664   0.420
# 3     [{'danceability': 0.701, 'energy': 0.571, 'key...         0.701   0.571
# 4     [{'danceability': 0.849, 'energy': 0.834, 'key...         0.849   0.834
# ...                                                 ...           ...     ...
# 4027  [{'danceability': 0.885, 'energy': 0.697, 'key...         0.885   0.697
# 4028  [{'danceability': 0.792, 'energy': 0.899, 'key...         0.792   0.899
# 4029  [{'danceability': 0.731, 'energy': 0.779, 'key...         0.731   0.779
# 4030  [{'danceability': 0.883, 'energy': 0.849, 'key...         0.883   0.849
# 4031  [{'danceability': 0.706, 'energy': 0.648, 'key...         0.706   0.648
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0      10    -5.802     0       0.2250       0.01610          0.000000
# 1       7    -6.397     1       0.3610       0.29900          0.000000
# 2       8    -9.508     1       0.1870       0.00961          0.000000
# 3       1    -5.906     1       0.3090       0.18900          0.000000
# 4       2    -4.642     1       0.2310       0.01230          0.000000
# ...   ...       ...   ...          ...           ...               ...
# 4027    2    -7.376     1       0.1980       0.23200          0.000000
# 4028    4    -5.626     0       0.0339       0.02990          0.000000
# 4029   11    -5.884     0       0.0658       0.60000          0.000002
# 4030    7    -5.088     1       0.1810       0.00697          0.000000
# 4031    8    -6.348     1       0.3240       0.50500          0.000000
#
#       liveness  valence    tempo            type                      id  \
# 0       0.0559    0.579  172.387  audio_features  2pMAmZdHfQHyqJCXJbfhK3
# 1       0.1730    0.323  130.022  audio_features  5tErNrwK58SgLMjZXJ5fdY
# 2       0.1180    0.177   74.935  audio_features  3oW1FNqsSJVgxjE9rqgpDX
# 3       0.0781    0.207  150.010  audio_features  2fcrnYXo5BP1RjzhIgV0v9
# 4       0.3070    0.517  133.971  audio_features  1cwGnaxEAu7fnt8YYROisL
# ...        ...      ...      ...             ...                     ...
# 4027    0.1150    0.715  151.510  audio_features  5KjeQtJQDFCMurnXYlpDz4
# 4028    0.2410    0.619  135.534  audio_features  1mf27pj8fn7GH4CehQxOtO
# 4029    0.3120    0.817  112.200  audio_features  59J3FhCGYl18G3ouDReUge
# 4030    0.0877    0.956   75.190  audio_features  5o0GRUA7okGPALKyEyQabz
# 4031    0.2150    0.802   77.533  audio_features  0judK8TqYfvwUohBngUxrE
#
#                                              track_href  duration_ms  \
# 0     https://api.spotify.com/v1/tracks/2pMAmZdHfQHy...       317507
# 1     https://api.spotify.com/v1/tracks/5tErNrwK58Sg...       121870
# 2     https://api.spotify.com/v1/tracks/3oW1FNqsSJVg...       160000
# 3     https://api.spotify.com/v1/tracks/2fcrnYXo5BP1...       130478
# 4     https://api.spotify.com/v1/tracks/1cwGnaxEAu7f...       172967
# ...                                                 ...          ...
# 4027  https://api.spotify.com/v1/tracks/5KjeQtJQDFCM...       217627
# 4028  https://api.spotify.com/v1/tracks/1mf27pj8fn7G...       231293
# 4029  https://api.spotify.com/v1/tracks/59J3FhCGYl18...       196733
# 4030  https://api.spotify.com/v1/tracks/5o0GRUA7okGP...       205333
# 4031  https://api.spotify.com/v1/tracks/0judK8TqYfvw...       161041
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 4027               4
# 4028               4
# 4029               4
# 4030               4
# 4031               4
#
# [4032 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['songs', 'artist', 'uri', 'audio_features', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id',
#        'track_href', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df_pre=df[['danceability','energy','key','loudness','mode','speechiness','acousticness','liveness','valence','tempo']]

# %%
df_pre
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.691   0.834   10    -5.802     0       0.2250       0.01610
# 1            0.547   0.737    7    -6.397     1       0.3610       0.29900
# 2            0.664   0.420    8    -9.508     1       0.1870       0.00961
# 3            0.701   0.571    1    -5.906     1       0.3090       0.18900
# 4            0.849   0.834    2    -4.642     1       0.2310       0.01230
# ...            ...     ...  ...       ...   ...          ...           ...
# 4027         0.885   0.697    2    -7.376     1       0.1980       0.23200
# 4028         0.792   0.899    4    -5.626     0       0.0339       0.02990
# 4029         0.731   0.779   11    -5.884     0       0.0658       0.60000
# 4030         0.883   0.849    7    -5.088     1       0.1810       0.00697
# 4031         0.706   0.648    8    -6.348     1       0.3240       0.50500
#
#       liveness  valence    tempo
# 0       0.0559    0.579  172.387
# 1       0.1730    0.323  130.022
# 2       0.1180    0.177   74.935
# 3       0.0781    0.207  150.010
# 4       0.3070    0.517  133.971
# ...        ...      ...      ...
# 4027    0.1150    0.715  151.510
# 4028    0.2410    0.619  135.534
# 4029    0.3120    0.817  112.200
# 4030    0.0877    0.956   75.190
# 4031    0.2150    0.802   77.533
#
# [4032 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler
X_features = StandardScaler().fit_transform(df_pre)

# Now, all features will have the same weight.
df_scale=pd.DataFrame(X_features,columns=df_pre.columns)

# %%
df_scale.shape
# Out:
# (4032, 10)

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.cluster import KMeans

# %%
import numpy as np
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(df_scale)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(df_scale)
    silhouette.append(silhouette_score(df_scale, kmeans.predict(df_scale)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state=1234)
kmeans.fit(df_scale)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(random_state=1234)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(df_scale)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    655
# 1    478
# 2    429
# 3    772
# 4    295
# 5    476
# 6    337
# 7    590
# dtype: int64

# %%
df.columns
# Out:
# Index(['songs', 'artist', 'uri', 'audio_features', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id',
#        'track_href', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
recommend_df=df[["artist","songs"]]
recommend_df
# Out:
#                   artist                                              songs
# 0                Outkast                    Southernplayalisticadillacmuzik
# 1                Carnage  Learn How to Watch (feat. Mac Miller & MadeinTYO)
# 2                  BIG30                   Allegations (feat. Pooh Shiesty)
# 3           Pooh Shiesty                                       No Profanity
# 4                G Herbo                                          All Black
# ...                  ...                                                ...
# 4027         Project Pat                                 Still Ridin' Clean
# 4028       Three 6 Mafia  Stay Fly (feat. Slim Thug, Trick Daddy & Proje...
# 4029         Johnny Cash                               I've Been Everywhere
# 4030         Project Pat                                    Cheese and Dope
# 4031  Tyler, The Creator                                           DOGTOOTH
#
# [4032 rows x 2 columns]

# %%
recommend_df["Clusters"]=clusters
recommend_df
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15012/1074427187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recommend_df["Clusters"]=clusters
#                   artist                                              songs  \
# 0                Outkast                    Southernplayalisticadillacmuzik
# 1                Carnage  Learn How to Watch (feat. Mac Miller & MadeinTYO)
# 2                  BIG30                   Allegations (feat. Pooh Shiesty)
# 3           Pooh Shiesty                                       No Profanity
# 4                G Herbo                                          All Black
# ...                  ...                                                ...
# 4027         Project Pat                                 Still Ridin' Clean
# 4028       Three 6 Mafia  Stay Fly (feat. Slim Thug, Trick Daddy & Proje...
# 4029         Johnny Cash                               I've Been Everywhere
# 4030         Project Pat                                    Cheese and Dope
# 4031  Tyler, The Creator                                           DOGTOOTH
#
#       Clusters
# 0            2
# 1            2
# 2            0
# 3            0
# 4            7
# ...        ...
# 4027         7
# 4028         3
# 4029         3
# 4030         7
# 4031         7
#
# [4032 rows x 3 columns]

# %%
recommend_df.to_csv("recommend_df.csv", index=False) # clusters with songs
